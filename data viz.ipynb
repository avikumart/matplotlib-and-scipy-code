# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #for plotting data
import seaborn as sns #statistical data visualization
import matplotlib as mpl
# %matplotlib inline

# %%
df=pd.read_csv('Latest Covid-19 India Status.csv')
print(df.head())
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar         7641       9        7503     129          0.12
# 1       Andhra Pradesh      2059708    6453     2038960   14295          0.31
# 2    Arunachal Pradesh        54964     183       54501     280          0.33
# 3                Assam       605944    3458      596547    5939          0.57
# 4                Bihar       726021      46      716314    9661          0.01
#
#    Discharge Ratio  Death Ratio
# 0            98.19         1.69
# 1            98.99         0.69
# 2            99.16         0.51
# 3            98.45         0.98
# 4            98.66         1.33

# %%
df.plot(kind='bar', x='State/UTs', y='Active',color="red", figsize=(15,6),
        title="Active cases by states")
# Out:
# <AxesSubplot:title={'center':'Active cases by states'}, xlabel='State/UTs'>
